# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
                'gradient_penalty': [244.219526290893555, 172.99060821533203, 201.3239288330078, 209.0687255859375, 249.6088256835938],
                'clip': [155.87890625, 13.820730209350586, 4.90239143371582, 2.296093463897705, 3.78859543800354],
                # 'clip_0.01': [63.64209747314453, 44.22629928588867, 202.87747192382812, 292.75848388671875, 1091.641845703125]
                }, index=range(0, 5))

# %%
df.apply(np.log10).plot()
# Out:
# <AxesSubplot:>
